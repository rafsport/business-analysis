# %%
import pandas as pd
import os
import numpy as np
import datetime as dt

# %%
df = pd.read_excel(r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\Dashboard rinnovi\20220310_dati dash_diretta_01.03.2022_FEBBRAIO22.xlsx")

# %%
df
# Out:
#       Tipo Partner Agg   Sales Director             Agente Cod. Agente  \
# 0                  NaN              NaN                NaN         NaN
# 1              Diretto  WKIC NORD OVEST  LUCERTONI MASSIMO        K170
# 2              Diretto  WKIC NORD OVEST  LUCERTONI MASSIMO        K170
# 3              Diretto  WKIC NORD OVEST  LUCERTONI MASSIMO        K170
# 4              Diretto  WKIC NORD OVEST  LUCERTONI MASSIMO        K170
# ...                ...              ...                ...         ...
# 21015          Diretto    WKIC NORD EST  GAVASSO NAZZARENA        K124
# 21016          Diretto    WKIC NORD EST      CALGARO PAOLA        K005
# 21017          Diretto    WKIC NORD EST       METTE ILARIA        K175
# 21018          Diretto    WKIC NORD EST    CARETTA BARBARA        K199
# 21019          Diretto    WKIC NORD EST      CALGARO PAOLA        K005
#
#       RSM Agente Descr. New Current State New Delta Type  Cliente FATTURA  \
# ...

# %%
df.iloc[1:,:].groupby(["New Current State", "New Delta Type"]).agg({"Opening 2022":"sum"}).unstack(level=0).fillna(0).style.format("{:,.0f}").background_gradient(axis=None, vmax=100000, vmin=1000)
# Out:
# <style type="text/css">
# ...
