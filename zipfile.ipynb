# %%
import zipfile

# %%
zip_file =r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\E-commerce\Data export\ZQ_MC_BUDANAL_IMP_ALL.zip"
file_to_extract = r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\E-commerce\Data export\prova.xls"

# %%
try:
    with zipfile.ZipFile(zip_file) as z:
        with open(file_to_extract, 'wb') as f:
            f.write(z.read(file_to_extract))
            print("Extracted", file_to_extract)
except:
    print("Invalid file")
# Out:
# Invalid file

# %%
zip_file =r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\Dashboard inflow\Dashboard inflow canali e prodotti\Data export\ZQ_MC_BUDANAL_IMP_ALL.zip"
directory_to_extract_to = r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\Dashboard inflow\Dashboard inflow canali e prodotti\Data export"

try:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(directory_to_extract_to)
except:
    print("Invalid file")

# %%
import pandas as pd

# %%
zip_file =r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\E-commerce\Data export\ZQ_MC_BUDANAL_IMP_ALL.ZIP"
directory_to_extract_to = r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\E-commerce\Data export"
try:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(directory_to_extract_to)
except:
    print("Invalid file")

# %%
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
bw_file = r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\E-commerce\Data export\ZQ_MC_BUDANAL_IMP_ALL_00000.xls"
df = pd.DataFrame(pd.read_html(str(bw_file), encoding = 'utf-8', decimal=",", thousands='.')[3])
df2 = pd.DataFrame(data=df.loc[1:,:])
df2.columns = df.loc[0,:].to_list()

# %%
df2
# Out:
#     Data Ins. Ordine (monitoraggio)        Prodotto (SW)  \
# 1                          03012022              WEBDESK
# 2                          04012022              WEBDESK
# 3                          10012022  CONSERVAZIONE SMART
# 4                          10012022  CONSERVAZIONE SMART
# 5                          10012022  CONSERVAZIONE SMART
# ..                              ...                  ...
# 645                        20042022              WEBDESK
# 646                        21042022              WEBDESK
# 647                        21042022              WEBDESK
# 648                        21042022              WEBDESK
# 649                        22042022              WEBDESK
#
#                   Soluzione (SW) Codice PRODOTTO Numero Ordine  \
# 1    FATTURA SMART COLLABORATION          239315    AI07405794
# 2    FATTURA SMART COLLABORATION          239315    AI07408086
# 3            CONSERVAZIONE SMART          245885    AI07393088
# 4            CONSERVAZIONE SMART          245885    AI07393223
# 5            CONSERVAZIONE SMART          245885    AI07393243
# ..                           ...             ...           ...
# 645            SMART SKILL ESHOP          257777    AI08206019
# 646  FATTURA SMART COLLABORATION          239315    AI08202306
# 647            SMART SKILL ESHOP          257795    AI08220845
# 648            SMART SKILL ESHOP          257797    AI08220293
# 649            SMART SKILL ESHOP          257795    AI08227397
#
#     Cliente FATTURA    Agente dell'ORDINE Raccolto
# 1           3051442  AREA METROPOL.ITALIA   120.00
# 2           3056704      GIAMBANET S.R.L.   120.00
# 3           3060764  AREA METROPOL.ITALIA    30.00
# 4           3060762       BONELLO GIORGIO    30.00
# 5           3060761  AREA METROPOL.ITALIA    30.00
# ..              ...                   ...      ...
# 645         3071780          SERIN S.A.S.     7.20
# 646         3071865   BRESCIANINI NICCOLÒ    90.00
# 647         3071954     CASTALDO RAFFAELE     7.20
# 648         3071955  AREA METROPOL.ITALIA     9.00
# 649         3063797            VERSYA SRL     7.20
#
# [649 rows x 8 columns]
