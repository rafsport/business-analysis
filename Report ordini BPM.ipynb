# %%
import pandas as pd
import os
import numpy as np
import datetime as dt

# %%
df = pd.read_csv(r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\Analisi flussi di lavoro\Registro Ordini_Report Ordini ALL Anno Corrente_202211181530.csv", sep=";", encoding="utf-8", lineterminator="\n")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df = pd.read_csv(r"C:\Users\Raffaele.Sportiello\OneDrive - Wolters Kluwer\Documents\Analisi flussi di lavoro\Registro Ordini_Report Ordini ALL Anno Corrente_202211181530.csv", sep=";", encoding="utf-8", lineterminator="\n")
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36408 entries, 0 to 36407
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod Pratica BPM        36408 non-null  object
#  1   N. Ordine              36408 non-null  object
#  2   Canale                 36378 non-null  object
#  3   Opportunity            19604 non-null  object
#  4   Dt Documento           36408 non-null  object
#  5   Denominazione Cliente  36408 non-null  object
#  6   Formato Allegato       36408 non-null  object
#  7   Produzione             36408 non-null  object
#  8   Org Comm               36408 non-null  object
#  9   Pratica BPM Ordine     36408 non-null  object
#  10  Fase Ordine Agenti     2437 non-null   object
#  11  Fase Ordine BPM        36408 non-null  object
#  12  Dt Ingresso BPM        36408 non-null  object
#  13  Cod Sales              36408 non-null  object
# ...

# %%
df.loc[:,["Data Documento", "Data Trasmissione", "Data Lavorazione", "Cust Code SAP"]]
# Out:
#       Data Documento Data Trasmissione Data Lavorazione        Cust Code SAP
# 0               2250               NaN              NaN  18/11/2022 00:00:00
# 1                525               NaN              NaN  17/11/2022 00:00:00
# 2                490               490              NaN  16/11/2022 00:00:00
# 3                250               250              NaN  17/11/2022 00:00:00
# 4                 50               NaN              NaN  18/11/2022 00:00:00
# ...              ...               ...              ...                  ...
# 36403            NaN               NaN              NaN  03/01/2022 00:00:00
# 36404            NaN               NaN              NaN  03/01/2022 00:00:00
# 36405            819               NaN              NaN  03/01/2022 00:00:00
# 36406            230               NaN              NaN  03/01/2022 00:00:00
# 36407        1593,50               NaN              NaN  29/12/2021 00:00:00
#
# [36408 rows x 4 columns]
